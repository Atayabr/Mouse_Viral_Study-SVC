# %% [markdown]
# ## 42&43 section

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

# %%
df = pd.read_csv("mouse_viral_study.csv")
df.head()
# Out:
#    Med_1_mL  Med_2_mL  Virus Present
# 0  6.508231  8.582531              0
# 1  4.126116  3.073459              1
# 2  6.427870  6.369758              0
# 3  3.672953  4.905215              1
# 4  1.580321  2.440562              1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Med_1_mL       400 non-null    float64
#  1   Med_2_mL       400 non-null    float64
#  2   Virus Present  400 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 9.5 KB

# %%
df["Virus Present"].value_counts()
# Out:
# 0    200
# 1    200
# Name: Virus Present, dtype: int64

# %%
sns.scatterplot(x="Med_1_mL", y="Med_2_mL", hue="Virus Present", data=df)
# Out:
# <AxesSubplot:xlabel='Med_1_mL', ylabel='Med_2_mL'>

# %%
sns.scatterplot(x="Med_1_mL", y="Med_2_mL", hue="Virus Present", data=df)

x = np.linspace(0,10,100)
m = -1
b = 11
y = m*x+b

plt.plot(x,y,"black")

# %%
x = df.drop("Virus Present", axis=1)

y = df["Virus Present"]

# %%
model = SVC(kernel="linear", C=1000)

model.fit(x,y)
# Out:
# SVC(C=1000, kernel='linear')

# %%
from svm_margin_plot import plot_svm_boundary

# %%
plot_svm_boundary(model,x,y)
# Out:
# C:\Users\Inspiron 7373\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
model = SVC(kernel="linear", C=0.05)

model.fit(x,y)

plot_svm_boundary(model,x,y)
# Out:
# C:\Users\Inspiron 7373\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
model = SVC(kernel="rbf", C=1000)

model.fit(x,y)

plot_svm_boundary(model,x,y)
# Out:
# C:\Users\Inspiron 7373\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
model = SVC(kernel="rbf", C=1)

model.fit(x,y)

plot_svm_boundary(model,x,y)
# Out:
# C:\Users\Inspiron 7373\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
model = SVC(kernel="rbf", C=1, gamma="auto")

model.fit(x,y)

plot_svm_boundary(model,x,y)
# Out:
# C:\Users\Inspiron 7373\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
model = SVC(kernel="poly", degree=2)

model.fit(x,y)

plot_svm_boundary(model,x,y)
# Out:
# C:\Users\Inspiron 7373\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
model = SVC(kernel="sigmoid", C=1)

model.fit(x,y)

plot_svm_boundary(model,x,y)
# Out:
# C:\Users\Inspiron 7373\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
svc = SVC()

param_grid = {"C":[0.01, 0,1,1], "kernel":["linear", "rbf"]}

grid =GridSearchCV(svc,param_grid)

# %%
grid.fit(x,y)
# Out:
# C:\Users\Inspiron 7373\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 10 fits failed out of a total of 40.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Inspiron 7373\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Inspiron 7373\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 255, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "C:\Users\Inspiron 7373\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 315, in _dense_fit
#     ) = libsvm.fit(
#   File "sklearn\svm\_libsvm.pyx", line 189, in sklearn.svm._libsvm.fit
# ValueError: C <= 0
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Inspiron 7373\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [ 1.  1. nan nan  1.  1.  1.  1.]
#   warnings.warn(
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.01, 0, 1, 1], 'kernel': ['linear', 'rbf']})

# %%
grid.best_params_
# Out:
# {'C': 0.01, 'kernel': 'linear'}
